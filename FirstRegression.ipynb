# %% [markdown]
# <a href="https://colab.research.google.com/github/JonJonDavidoff/DeepLearningCourse/blob/main/FirstRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %% [markdown]
# # Y module function

# %%
moduleFuncW = 5
moduleFuncB = 5
dataSet =[[15,34.7],[46,105.7],[45,80.6],[60,118],[67,136],[54,101],[73,146],[17,15],[68,119],[59,114],[12,48.7],[7,45],[31,69.2],[69,136],[92,185]]
def calculate_module_y(moduleFuncW : float, moduleFuncB:float, x : float, ):
    return (moduleFuncW * x ) + moduleFuncB

# %% [markdown]
# # calculate error **function**

# %%
def calculate_error(moduleY : float , y : float):
    return math.pow((moduleY - y),2)

# %% [markdown]
# # calculate price prediction function

# %%
def price_func(dataSet, moduleFuncW,moduleFuncB ):
  sum = 0
  ds_size = size(dataSet)
  error = 0
  point = None
  for i in range(ds_size):
    point = dataSet[i]
    size += 1
    error = calculateError(calculateModuleY(moduleFuncW,moduleFuncB, x= point[0]), point[1])
    sum += error
  return  sum/size

# %% [markdown]
# # New section

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([15, 46, 45, 60, 67, 54, 73, 17, 68, 59, 12, 7, 31, 69, 92])
y = np.array([34.7, 105.7, 80.6, 118, 136, 101, 146, 15, 119, 114, 48.7, 45, 69.2, 136, 185])
# dataSet = [[15, 34.7], [46, 105.7], [45, 80.6], [60, 118], [67, 136], [54, 101], [73, 146], [17, 15], [68, 119],
#            [59, 114], [12, 48.7], [7, 45], [31, 69.2], [69, 136], [92, 185]]
plt.scatter(x, y)
x_line = np.linspace(0, 100)
print(x_line)
y_line = 2*x_line + 1

plt.plot(x_line, y_line)
plt.show()
# Out:
# [  0.           2.04081633   4.08163265   6.12244898   8.16326531
#   10.20408163  12.24489796  14.28571429  16.32653061  18.36734694
#   20.40816327  22.44897959  24.48979592  26.53061224  28.57142857
#   30.6122449   32.65306122  34.69387755  36.73469388  38.7755102
#   40.81632653  42.85714286  44.89795918  46.93877551  48.97959184
#   51.02040816  53.06122449  55.10204082  57.14285714  59.18367347
#   61.2244898   63.26530612  65.30612245  67.34693878  69.3877551
#   71.42857143  73.46938776  75.51020408  77.55102041  79.59183673
#   81.63265306  83.67346939  85.71428571  87.75510204  89.79591837
#   91.83673469  93.87755102  95.91836735  97.95918367 100.        ]

# %%
price_func(dataSet, moduleFuncW,moduleFuncB )
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-20-538a1396c2b1> in <module>()
# ----> 1 price_func(dataSet, moduleFuncW,moduleFuncB )
#
# <ipython-input-19-d03bde5d5d9f> in price_func(dataSet, moduleFuncW, moduleFuncB)
#       1 def price_func(dataSet, moduleFuncW,moduleFuncB ):
#       2   sum = 0
# ----> 3   ds_size = size(dataSet)
#       4   error = 0
#       5   point = None
#
# UnboundLocalError: local variable 'size' referenced before assignment
